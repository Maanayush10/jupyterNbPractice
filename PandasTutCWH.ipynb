# %%
import numpy as np
import pandas as pd

# %%
dict1 ={
    "name" : ['Harry', 'Ayushman', 'Sarveshwari', 'Suman'],
    "marks":[20, 99, 99, 10],
    "city" :['Patna', 'Mumbai' ,'Karwar', 'Delhi']
}

# %%
df = pd.DataFrame(dict1)

# %%
print(df)
# Out:
#           name  marks    city
# 0        Harry     20   Patna
# 1     Ayushman     99  Mumbai
# 2  Sarveshwari     99  Karwar
# 3        Suman     10   Delhi

# %%
df
# Out:
#           name  marks    city
# 0        Harry     20   Patna
# 1     Ayushman     99  Mumbai
# 2  Sarveshwari     99  Karwar
# 3        Suman     10   Delhi

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_indexFalse.csv', index= False)

# %%
df
# Out:
#           name  marks    city
# 0        Harry     20   Patna
# 1     Ayushman     99  Mumbai
# 2  Sarveshwari     99  Karwar
# 3        Suman     10   Delhi

# %%
df.head(2)
# Out:
#        name  marks    city
# 0     Harry     20   Patna
# 1  Ayushman     99  Mumbai

# %%
df.tail(2)
# Out:
#           name  marks    city
# 2  Sarveshwari     99  Karwar
# 3        Suman     10   Delhi

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   57.00000
# std    48.66895
# min    10.00000
# 25%    17.50000
# 50%    59.50000
# 75%    99.00000
# max    99.00000

# %%
GDP= pd.read_csv('gdp.csv')

# %%
GDP
# Out:
#           Series_reference   Period  Data_value   STATUS    UNITS  MAGNTUDE  \
# 0        SNEA.SG00NAC00B15  1972.03      6990.0    FINAL  Dollars         6
# 1        SNEA.SG00NAC00B15  1973.03      8080.0    FINAL  Dollars         6
# 2        SNEA.SG00NAC00B15  1974.03      9361.0    FINAL  Dollars         6
# 3        SNEA.SG00NAC00B15  1975.03     10203.0    FINAL  Dollars         6
# 4        SNEA.SG00NAC00B15  1976.03     11506.0    FINAL  Dollars         6
# ...                    ...      ...         ...      ...      ...       ...
# 86943  SNEQ.SG09RSC00B15NZ  2021.09     13145.0  REVISED  Dollars         0
# 86944  SNEQ.SG09RSC00B15NZ  2021.12     13449.0  REVISED  Dollars         0
# 86945  SNEQ.SG09RSC00B15NZ  2022.03     13408.0  REVISED  Dollars         0
# 86946  SNEQ.SG09RSC00B15NZ  2022.06     13717.0  REVISED  Dollars         0
# 86947  SNEQ.SG09RSC00B15NZ  2022.09     13977.0    FINAL  Dollars         0
#
#                                   Subject  \
# ...

# %%
GDP.tail()
# Out:
#           Series_reference   Period  Data_value   STATUS    UNITS  MAGNTUDE  \
# 86943  SNEQ.SG09RSC00B15NZ  2021.09     13145.0  REVISED  Dollars         0
# 86944  SNEQ.SG09RSC00B15NZ  2021.12     13449.0  REVISED  Dollars         0
# 86945  SNEQ.SG09RSC00B15NZ  2022.03     13408.0  REVISED  Dollars         0
# 86946  SNEQ.SG09RSC00B15NZ  2022.06     13717.0  REVISED  Dollars         0
# 86947  SNEQ.SG09RSC00B15NZ  2022.09     13977.0    FINAL  Dollars         0
#
#                                   Subject  \
# 86943  National Accounts - SNA 2008 - SNE
# 86944  National Accounts - SNA 2008 - SNE
# 86945  National Accounts - SNA 2008 - SNE
# 86946  National Accounts - SNA 2008 - SNE
# 86947  National Accounts - SNA 2008 - SNE
#
#                                                    Group  \
# 86943  Series, Per capita measure, Chain volume, Seas...
# 86944  Series, Per capita measure, Chain volume, Seas...
# 86945  Series, Per capita measure, Chain volume, Seas...
# ...

# %%
ls
# Out:
#  200905128_AYUSHMAN/                    input2.c
# '200905128_AYUSHMAN DSAL.pdf'           lab8q1.c
#  200905128_AYUSHMAN_LAB5_OSTL.pdf       lab8q2.c
#  200905128_AYUSHMAN_OSTL_ENDSEM.pdf     labensem.c
#  200905128_OSTL6_AYUSHMAN.pdf           linux-5.15.74.tar.xz
#  200905149/                             maan/
#  Android/                               Maan/
#  AndroidStudioProjects/                 Main.class
#  board21-22cert/                        Main.java
#  canvas.html                            mOm
#  capture_file                           Music/
#  cnSylabus                              myApp/
#  compilePapers.zip                      myCap#1.pcapng
#  demons.class                           myWebsite/
#  Desktop/                               Nexttoken.h
#  django/                                note
#  doc                                    notHand.class
#  Documents/                             notHand.java
#  Downloads/                             oddProg2.sh*
# ...

# %%
df
# Out:
#           name  marks    city
# 0        Harry     20   Patna
# 1     Ayushman     99  Mumbai
# 2  Sarveshwari     99  Karwar
# 3        Suman     10   Delhi

# %%
df.index=['First', 'Second','Third', 'Fourth']

# %%
df
# Out:
#                name  marks    city
# First         Harry     20   Patna
# Second     Ayushman     99  Mumbai
# Third   Sarveshwari     99  Karwar
# Fourth        Suman     10   Delhi

# %%
s = pd.Series(np.random.rand(10))

# %%
s
# Out:
# 0    0.046885
# 1    0.340740
# 2    0.113956
# 3    0.970169
# 4    0.503820
# 5    0.019906
# 6    0.609065
# 7    0.639505
# 8    0.559435
# 9    0.238539
# dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
df2 = pd.DataFrame(np.random.rand(10,5), index= np.arange(10))

# %%
df2
# Out:
#           0         1         2         3         4
# 0  0.809333  0.319193  0.876833  0.033748  0.537417
# 1  0.471288  0.098593  0.700901  0.455750  0.894836
# 2  0.726492  0.953057  0.958573  0.036577  0.827720
# 3  0.455365  0.353551  0.849688  0.200522  0.744976
# 4  0.736794  0.532857  0.436257  0.063577  0.557431
# 5  0.379849  0.954606  0.622734  0.545340  0.695613
# 6  0.047336  0.451986  0.443644  0.972613  0.868563
# 7  0.842587  0.291780  0.891186  0.769771  0.608929
# 8  0.994741  0.477729  0.585698  0.981067  0.063715
# 9  0.367513  0.124174  0.356872  0.176009  0.492652

# %%
df2.describe()
# Out:
#                0          1          2          3          4
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.583130   0.455753   0.672239   0.423497   0.629185
# std     0.285929   0.297414   0.216393   0.378642   0.244378
# min     0.047336   0.098593   0.356872   0.033748   0.063715
# 25%     0.398728   0.298633   0.479158   0.091685   0.542420
# 50%     0.598890   0.402769   0.661818   0.328136   0.652271
# 75%     0.791198   0.519075   0.870047   0.713663   0.807034
# max     0.994741   0.954606   0.958573   0.981067   0.894836

# %%
df2.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df2.summary()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'summary'

# %%
df2.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
df2[0][0]="Ayushman"

# %%
df2
# Out:
#           0         1         2         3         4
# 0  Ayushman  0.319193  0.876833  0.033748  0.537417
# 1  0.471288  0.098593  0.700901  0.455750  0.894836
# 2  0.726492  0.953057  0.958573  0.036577  0.827720
# 3  0.455365  0.353551  0.849688  0.200522  0.744976
# 4  0.736794  0.532857  0.436257  0.063577  0.557431
# 5  0.379849  0.954606  0.622734  0.545340  0.695613
# 6  0.047336  0.451986  0.443644  0.972613  0.868563
# 7  0.842587  0.291780  0.891186  0.769771  0.608929
# 8  0.994741  0.477729  0.585698  0.981067  0.063715
# 9  0.367513  0.124174  0.356872  0.176009  0.492652

# %%
df2.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
df
# 2  0.726492  0.953057  0.958573     0.036577      0.82772
# 1  0.471288  0.098593  0.700901      0.45575     0.894836
# 0  Ayushman  0.319193  0.876833     0.033748     0.537417

# %%
df2.sort_index(axis =0)
# Out:
#           0         1         2            3            4
# 0  Ayushman  0.319193  0.876833     0.033748     0.537417
# 1  0.471288  0.098593  0.700901      0.45575     0.894836
# 2  0.726492  0.953057  0.958573     0.036577      0.82772
# 3  0.455365  0.353551  0.849688     0.200522     0.744976
# 4  0.736794  0.532857  0.436257     0.063577     0.557431
# 5  0.379849  0.954606  0.622734  Sarveshwari  Sarveshwari
# 6  0.047336  0.451986  0.443644     0.972613     0.868563
# 7  0.842587  0.291780  0.891186     0.769771     0.608929
# 8  0.994741  0.477729  0.585698     0.981067     0.063715
# 9  0.367513  0.124174  0.356872     0.176009     0.492652

# %%
df2.sort_index(axis =1, ascending =False) #axis 1 is for columns
# Out:
#              4            3         2         1         0
# 0     0.537417     0.033748  0.876833  0.319193  Ayushman
# 1     0.894836      0.45575  0.700901  0.098593  0.471288
# 2      0.82772     0.036577  0.958573  0.953057  0.726492
# 3     0.744976     0.200522  0.849688  0.353551  0.455365
# 4     0.557431     0.063577  0.436257  0.532857  0.736794
# 5  Sarveshwari  Sarveshwari  0.622734  0.954606  0.379849
# 6     0.868563     0.972613  0.443644  0.451986  0.047336
# 7     0.608929     0.769771  0.891186  0.291780  0.842587
# 8     0.063715     0.981067  0.585698  0.477729  0.994741
# 9     0.492652     0.176009  0.356872  0.124174  0.367513

# %%
df2=df2.drop(2, axis=1)

# %%
df2
# Out:
#           0         1            3            4
# 0  Ayushman  0.319193     0.033748     0.537417
# 1  0.471288  0.098593      0.45575     0.894836
# 2  0.726492  0.953057     0.036577      0.82772
# 3  0.455365  0.353551     0.200522     0.744976
# 4  0.736794  0.532857     0.063577     0.557431
# 5  0.379849  0.954606  Sarveshwari  Sarveshwari
# 6  0.047336  0.451986     0.972613     0.868563
# 7  0.842587  0.291780     0.769771     0.608929
# 8  0.994741  0.477729     0.981067     0.063715
# 9  0.367513  0.124174     0.176009     0.492652

# %%
df2.loc[[0,5],[0,3]]
# Out:
#           0            3
# 0  Ayushman     0.033748
# 5  0.379849  Sarveshwari

# %%
df2.loc[:,[0,3] ]
# Out:
#           0            3
# 0  Ayushman     0.033748
# 1  0.471288      0.45575
# 2  0.726492     0.036577
# 3  0.455365     0.200522
# 4  0.736794     0.063577
# 5  0.379849  Sarveshwari
# 6  0.047336     0.972613
# 7  0.842587     0.769771
# 8  0.994741     0.981067
# 9  0.367513     0.176009

# %%
df2.loc[[0,5],:]
# Out:
#           0         1            3            4
# 0  Ayushman  0.319193     0.033748     0.537417
# 5  0.379849  0.954606  Sarveshwari  Sarveshwari

# %%
df2.loc[(df2[0]<0.3)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df2.loc[(df2[0]<0.3)]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# ...
